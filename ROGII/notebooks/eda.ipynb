# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("../data/train/0a57a29c__horizontal_well.csv")

print(train.head())
print(train.info())
print(train.describe())
print(train.isnull().sum())
print(train.isnull().sum()/len(train))
# Out:
#         MD           X           Y        Z     ANCC    ASTNU    ASTNL  \
# 0  10712.0  2903864.38  1030782.87 -8669.51 -8750.30 -8973.74 -9040.12
# 1  10713.0  2903864.36  1030782.88 -8670.51 -8750.33 -8973.77 -9040.15
# 2  10714.0  2903864.35  1030782.88 -8671.51 -8750.36 -8973.80 -9040.18
# 3  10715.0  2903864.33  1030782.88 -8672.51 -8750.39 -8973.83 -9040.21
# 4  10716.0  2903864.31  1030782.88 -8673.51 -8750.42 -8973.86 -9040.24
#
#      EGFDU    EGFDL     BUDA       TVT         GR  TVT_input
# 0 -9089.64 -9127.68 -9253.99  10681.71  83.260428   10681.71
# 1 -9089.67 -9127.71 -9254.02  10682.68  81.414299   10682.68
# 2 -9089.70 -9127.73 -9254.05  10683.65        NaN   10683.65
# 3 -9089.73 -9127.76 -9254.08  10684.62        NaN   10684.62
# 4 -9089.76 -9127.79 -9254.11  10685.59        NaN   10685.59
# <class 'pandas.DataFrame'>
# RangeIndex: 7194 entries, 0 to 7193
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ...
